# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.3.5

# %%
data = pd.read_csv("adult.data.csv")

# %%
column_names
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country',
#  'salary']

# %%
data
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
data.shape
# Out:
# (32561, 15)

# %%
sample_data = data.sample(n=3000, random_state=42)

# %%
data = pd.read_csv(data_path, names=column_names, na_values="?", skipinitialspace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25632\3381138390.py in <module>
# ----> 1 data = pd.read_csv(data_path, names=column_names, na_values="?", skipinitialspace=True)
#
# NameError: name 'data_path' is not defined

# %%
sample_data.head()
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 14160   27           Private  160178  Some-college             10
# 27048   45         State-gov   50567       HS-grad              9
# 28868   29           Private  185908     Bachelors             13
# 5667    30           Private  190040     Bachelors             13
# 7827    29  Self-emp-not-inc  189346  Some-college             10
#
#            marital-status         occupation   relationship   race     sex  \
# 14160            Divorced       Adm-clerical  Not-in-family  White  Female
# 27048  Married-civ-spouse    Exec-managerial           Wife  White  Female
# 28868  Married-civ-spouse    Exec-managerial        Husband  Black    Male
# 5667        Never-married  Machine-op-inspct  Not-in-family  White  Female
# 7827             Divorced       Craft-repair  Not-in-family  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# ...

# %%
column_names
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country',
#  'salary']

# %%
sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3000 entries, 14160 to 13707
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             3000 non-null   int64
#  1   workclass       3000 non-null   object
#  2   fnlwgt          3000 non-null   int64
#  3   education       3000 non-null   object
#  4   education-num   3000 non-null   int64
#  5   marital-status  3000 non-null   object
#  6   occupation      3000 non-null   object
#  7   relationship    3000 non-null   object
#  8   race            3000 non-null   object
#  9   sex             3000 non-null   object
#  10  capital-gain    3000 non-null   int64
#  11  capital-loss    3000 non-null   int64
#  12  hours-per-week  3000 non-null   int64
#  13  native-country  3000 non-null   object
#  14  salary          3000 non-null   object
# dtypes: int64(6), object(9)
# memory usage: 375.0+ KB

# %% [markdown]
# # Alternative: Select a Percentage of the Dataset

# %%
sample_data = data.sample(n=3000, random_state=236)

# %%
sample_data
# Out:
#        age  workclass  fnlwgt     education  education-num  \
# 2220    22    Private  228452          10th              6
# 315     24    Private  191954  Some-college             10
# 6555    34    Private  144949          10th              6
# 25176   33  Local-gov  175509       HS-grad              9
# 26712   70    Private   89787       HS-grad              9
# ...    ...        ...     ...           ...            ...
# 19808   32    Private  207400       HS-grad              9
# 29797   46  Local-gov  345911  Some-college             10
# 19285   46  State-gov  170165       HS-grad              9
# 14164   20    Private  170091  Some-college             10
# 27251   49    Private   50748     Bachelors             13
#
#            marital-status         occupation   relationship   race     sex  \
# 2220        Never-married       Craft-repair  Not-in-family  White    Male
# 315         Never-married  Machine-op-inspct  Not-in-family  White    Male
# ...

# %%
sample_data.describe()
# Out:
#                age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  3000.000000  3.000000e+03    3000.000000   3000.000000   3000.000000
# mean     38.576333  1.876602e+05      10.010333    759.812333     84.946000
# std      13.521925  1.035477e+05       2.586334   5640.674163    404.765445
# min      17.000000  1.930200e+04       1.000000      0.000000      0.000000
# 25%      28.000000  1.168578e+05       9.000000      0.000000      0.000000
# 50%      37.000000  1.760565e+05      10.000000      0.000000      0.000000
# 75%      47.000000  2.347998e+05      12.000000      0.000000      0.000000
# max      90.000000  1.184622e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count     3000.000000
# mean        40.656333
# std         12.437542
# min          2.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
data.describe(include="all")
# Out:
#                  age workclass        fnlwgt education  education-num  \
# count   32561.000000     32561  3.256100e+04     32561   32561.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581647       NaN  1.897784e+05       NaN      10.080679
# std        13.640433       NaN  1.055500e+05       NaN       2.572720
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#             marital-status      occupation relationship   race    sex  \
# ...

# %%
sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3000 entries, 2220 to 27251
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             3000 non-null   int64
#  1   workclass       3000 non-null   object
#  2   fnlwgt          3000 non-null   int64
#  3   education       3000 non-null   object
#  4   education-num   3000 non-null   int64
#  5   marital-status  3000 non-null   object
#  6   occupation      3000 non-null   object
#  7   relationship    3000 non-null   object
#  8   race            3000 non-null   object
#  9   sex             3000 non-null   object
#  10  capital-gain    3000 non-null   int64
#  11  capital-loss    3000 non-null   int64
#  12  hours-per-week  3000 non-null   int64
#  13  native-country  3000 non-null   object
#  14  salary          3000 non-null   object
# dtypes: int64(6), object(9)
# memory usage: 375.0+ KB

# %%
sample_data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
sample_data.select_dtypes(include=["object"]).describe()
# Out:
#        workclass education      marital-status       occupation relationship  \
# count       3000      3000                3000             3000         3000
# unique         8        16                   7               15            6
# top      Private   HS-grad  Married-civ-spouse  Exec-managerial      Husband
# freq        2069       953                1369              366         1207
#
#          race   sex native-country salary
# count    3000  3000           3000   3000
# unique      5     2             38      2
# top     White  Male  United-States  <=50K
# freq     2557  2033           2670   2294

# %%
sample_data.to_csv("summary_statistics.csv")

# %%
sample_data
# Out:
#        age  workclass  fnlwgt     education  education-num  \
# 2220    22    Private  228452          10th              6
# 315     24    Private  191954  Some-college             10
# 6555    34    Private  144949          10th              6
# 25176   33  Local-gov  175509       HS-grad              9
# 26712   70    Private   89787       HS-grad              9
# ...    ...        ...     ...           ...            ...
# 19808   32    Private  207400       HS-grad              9
# 29797   46  Local-gov  345911  Some-college             10
# 19285   46  State-gov  170165       HS-grad              9
# 14164   20    Private  170091  Some-college             10
# 27251   49    Private   50748     Bachelors             13
#
#            marital-status         occupation   relationship   race     sex  \
# 2220        Never-married       Craft-repair  Not-in-family  White    Male
# 315         Never-married  Machine-op-inspct  Not-in-family  White    Male
# ...

# %%
sample_data.index
# Out:
# Int64Index([ 2220,   315,  6555, 25176, 26712,  6583, 32470,   576, 30662,
#               984,
#             ...
#              6076, 15218, 16772, 16556, 28466, 19808, 29797, 19285, 14164,
#             27251],
#            dtype='int64', length=3000)

# %%
sample_data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
if "education" in data.columns:
    bachelors_data = data[data["education"] == "Bachelors"]
    print(bachelors_data.head())
else:
    print("The column 'education' does not exist in the dataset.")
# Out:
#     age         workclass  fnlwgt  education  education-num  \
# 0    39         State-gov   77516  Bachelors             13
# 1    50  Self-emp-not-inc   83311  Bachelors             13
# 4    28           Private  338409  Bachelors             13
# 9    42           Private  159449  Bachelors             13
# 11   30         State-gov  141297  Bachelors             13
#
#         marital-status       occupation   relationship                race  \
# 0        Never-married     Adm-clerical  Not-in-family               White
# 1   Married-civ-spouse  Exec-managerial        Husband               White
# 4   Married-civ-spouse   Prof-specialty           Wife               Black
# 9   Married-civ-spouse  Exec-managerial        Husband               White
# 11  Married-civ-spouse   Prof-specialty        Husband  Asian-Pac-Islander
#
#        sex  capital-gain  capital-loss  hours-per-week native-country salary
# ...

# %%
print(data.columns)
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
data = data.drop(columns=["fnlwgt"])

# %%
# Select only numerical columns
numerical_cols = data.select_dtypes(include=["number"]).columns

# Plot the boxplot
plt.figure(figsize=(12, 6))
data[numerical_cols].boxplot(rot=45)  # Rotate labels for readability
plt.title("Boxplot of Numerical Features")
plt.xlabel("Features")
plt.ylabel("Values")
plt.show()

# %%
plt.figure(figsize=(6, 4))
data.boxplot(column="age")  # Replace "age" with your column
plt.title("Boxplot of Age")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure 'age' column exists
if "age" in data.columns:
    mean_age = data["age"].mean()
    median_age = data["age"].median()

    # Create a histogram with mean and median markers
    plt.figure(figsize=(6, 4))
    sns.histplot(data["age"], bins=30, kde=True, color="blue", alpha=0.6, label="Age Distribution")
    plt.axvline(mean_age, color="red", linestyle="dashed", linewidth=2, label=f"Mean Age: {mean_age:.2f}")
    plt.axvline(median_age, color="green", linestyle="dashed", linewidth=2, label=f"Median Age: {median_age:.2f}")

    plt.title("Comparison of Mean vs. Median Age")
    plt.xlabel("Age")
    plt.ylabel("Frequency")
    plt.legend()
    plt.show()

    # Print mean and median values
    print(f"Mean Age: {mean_age:.2f}")
    print(f"Median Age: {median_age:.2f}")

else:
    print("The column 'age' does not exist in the dataset.")
# Out:
# Mean Age: 38.58
# Median Age: 37.00

# %%
age_comparison = pd.DataFrame({"Statistic": ["Mean Age", "Median Age"], "Value": [mean_age, median_age]})
age_comparison.to_csv("age_comparison.csv", index=False)

# %%
age_comparison
# Out:
#     Statistic      Value
# 0    Mean Age  38.581647
# 1  Median Age  37.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Check if 'age' column exists
if "age" in data.columns:
    plt.figure(figsize=(8, 5))
    sns.histplot(data["age"], bins=30, kde=True, color="blue", alpha=0.6)

    plt.title("Histogram of Age Distribution")
    plt.xlabel("Age")
    plt.ylabel("Frequency")
    plt.show()
else:
    print("The column 'age' does not exist in the dataset.")

# %%
# Count occurrences of each gender in the dataset
gender_counts = data["sex"].value_counts().reset_index()
gender_counts.columns = ["Gender", "Count"]



# Plot the gender distribution
plt.figure(figsize=(6, 4))
sns.barplot(x=gender_counts["Gender"], y=gender_counts["Count"], palette="viridis")
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
print(data.columns)
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'salary'],
#       dtype='object')

# %%
data.columns = data.columns.str.strip().str.lower()  # Removes spaces and makes lowercase
print(data.columns)  # Check again
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'salary'],
#       dtype='object')

# %%
gender_counts = data["sex"].value_counts().reset_index()
gender_counts.columns = ["Gender", "Count"]

# %%
gender_counts
# Out:
#    Gender  Count
# 0    Male  21790
# 1  Female  10771

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count occurrences of each gender
gender_counts = data["sex"].value_counts().reset_index()
gender_counts.columns = ["Gender", "Count"]



# Plot the gender distribution
plt.figure(figsize=(6, 4))
sns.barplot(x=gender_counts["Gender"], y=gender_counts["Count"], palette="viridis")
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
print(data.columns)
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'salary'],
#       dtype='object')

# %%
gender_age = data.groupby("sex")["age"].mean().reset_index()
gender_age.columns = ["Gender", "Mean Age"]

# %%
gender_age
# Out:
#    Gender   Mean Age
# 0  Female  36.858230
# 1    Male  39.433547

# %%
education_counts = data.groupby("education").size().reset_index(name="Count")

education_counts
# Out:
#        education  Count
# 0           10th    933
# 1           11th   1175
# 2           12th    433
# 3        1st-4th    168
# 4        5th-6th    333
# 5        7th-8th    646
# 6            9th    514
# 7     Assoc-acdm   1067
# 8      Assoc-voc   1382
# 9      Bachelors   5355
# 10     Doctorate    413
# 11       HS-grad  10501
# 12       Masters   1723
# 13     Preschool     51
# 14   Prof-school    576
# 15  Some-college   7291

# %%
occupation_hours = data.groupby("occupation")["hours-per-week"].mean().reset_index()
occupation_hours.columns = ["Occupation", "Avg Hours per Week"]

# %%
occupation_hours
# Out:
#            Occupation  Avg Hours per Week
# 0                   ?           31.906131
# 1        Adm-clerical           37.558355
# 2        Armed-Forces           40.666667
# 3        Craft-repair           42.304221
# 4     Exec-managerial           44.987703
# 5     Farming-fishing           46.989940
# 6   Handlers-cleaners           37.947445
# 7   Machine-op-inspct           40.755744
# 8       Other-service           34.701669
# 9     Priv-house-serv           32.885906
# 10     Prof-specialty           42.386715
# 11    Protective-serv           42.870570
# 12              Sales           40.781096
# 13       Tech-support           39.432112
# 14   Transport-moving           44.656230

# %%
salary_capital_gain = data.groupby("salary")["capital-gain"].mean().reset_index()
salary_capital_gain.columns = ["Salary", "Avg Capital Gain"]
salary_capital_gain
# Out:
#   Salary  Avg Capital Gain
# 0  <=50K        148.752468
# 1   >50K       4006.142456

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
sns.barplot(x=occupation_hours["Occupation"], y=occupation_hours["Avg Hours per Week"], palette="viridis")
plt.xticks(rotation=90)
plt.title("Average Work Hours by Occupation")
plt.xlabel("Occupation")
plt.ylabel("Avg Hours per Week")
plt.show()

# %%
# Count occurrences of each workclass category
workclass_counts = data["workclass"].value_counts().reset_index()
workclass_counts.columns = ["Workclass", "Count"]



# Plot the workclass distribution
plt.figure(figsize=(8, 5))
sns.barplot(x=workclass_counts["Workclass"], y=workclass_counts["Count"], palette="viridis")
plt.xticks(rotation=90)
plt.title("Workclass Distribution")
plt.xlabel("Workclass")
plt.ylabel("Count")
plt.show()

# %%
print(data.columns)
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'salary'],
#       dtype='object')

# %%
data.columns = data.columns.str.strip().str.lower()
print(data.columns)  # Check again
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'salary'],
#       dtype='object')

# %%
workclass_counts = data["workclass"].value_counts().reset_index()
workclass_counts.columns = ["Workclass", "Count"]

# %%
workclass_counts
# Out:
#           Workclass  Count
# 0           Private  22696
# 1  Self-emp-not-inc   2541
# 2         Local-gov   2093
# 3                 ?   1836
# 4         State-gov   1298
# 5      Self-emp-inc   1116
# 6       Federal-gov    960
# 7       Without-pay     14
# 8      Never-worked      7

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count occurrences of each workclass category
workclass_counts = data["workclass"].value_counts().reset_index()
workclass_counts.columns = ["Workclass", "Count"]


# Plot the workclass distribution
plt.figure(figsize=(8, 5))
sns.barplot(x=workclass_counts["Workclass"], y=workclass_counts["Count"], palette="viridis")
plt.xticks(rotation=90)
plt.title("Workclass Distribution")
plt.xlabel("Workclass")
plt.ylabel("Count")
plt.show()

# %%
# Ensure column names are cleaned (remove spaces and lowercase)
data.columns = data.columns.str.strip().str.lower()

# Grouping by workclass and aggregating mean age, mean hours per week, and count of records
workclass_summary = data.groupby("workclass").agg(
    mean_age=("age", "mean"),
    mean_hours_per_week=("hours-per-week", "mean"),
    count=("workclass", "count")
).reset_index()


# Plot the average hours worked per week by workclass
plt.figure(figsize=(10, 5))
sns.barplot(x=workclass_summary["workclass"], y=workclass_summary["mean_hours_per_week"], palette="viridis")
plt.xticks(rotation=90)
plt.title("Average Hours Worked per Week by Workclass")
plt.xlabel("Workclass")
plt.ylabel("Avg Hours per Week")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Group by workclass and calculate mean age, mean hours per week, and count
workclass_summary = data.groupby("workclass").agg(
    mean_age=("age", "mean"),
    mean_hours_per_week=("hours-per-week", "mean"),
    count=("workclass", "count")
).reset_index()


# Plot the average hours worked per week by workclass
plt.figure(figsize=(10, 5))
sns.barplot(x=workclass_summary["workclass"], y=workclass_summary["mean_hours_per_week"], palette="viridis")
plt.xticks(rotation=90)
plt.title("Average Hours Worked per Week by Workclass")
plt.xlabel("Workclass")
plt.ylabel("Avg Hours per Week")
plt.show()

# %%
data.columns = data.columns.str.strip()

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'salary'],
#       dtype='object')

# %%
# Group by gender and calculate the average age
gender_age_summary = data.groupby("sex").agg(
    mean_age=("age", "mean")
).reset_index()


# Plot the average age by gender
plt.figure(figsize=(6, 4))
sns.barplot(x=gender_age_summary["sex"], y=gender_age_summary["mean_age"], palette="viridis")
plt.title("Average Age by Gender")
plt.xlabel("Gender")
plt.ylabel("Average Age")
plt.show()

# %%
print(data.columns)
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'salary'],
#       dtype='object')

# %%
# Ensure column names are cleaned (remove spaces and lowercase)
data.columns = data.columns.str.strip().str.lower()

# Summary statistics for capital-gain
capital_gain_summary = data["capital-gain"].describe().reset_index()
capital_gain_summary.columns = ["Statistic", "Value"]


# Plot the distribution of capital-gain
plt.figure(figsize=(8, 5))
sns.histplot(data["capital-gain"], bins=30, kde=True, color="blue", alpha=0.6)
plt.title("Distribution of Capital-Gain")
plt.xlabel("Capital-Gain")
plt.ylabel("Frequency")
plt.show()

# %%
# Reload dataset with correct headers in case of misalignment
column_names = [
    "age", "workclass", "fnlwgt", "education", "education-num", "marital-status",
    "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss",
    "hours-per-week", "native-country", "salary"
]


# Summary statistics for capital-gain
capital_gain_summary = data["capital-gain"].describe().reset_index()
capital_gain_summary.columns = ["Statistic", "Value"]


# Plot the distribution of capital-gain
plt.figure(figsize=(8, 5))
sns.histplot(data["capital-gain"], bins=30, kde=True, color="blue", alpha=0.6)
plt.title("Distribution of Capital-Gain")
plt.xlabel("Capital-Gain")
plt.ylabel("Frequency")
plt.show()

# %%
# Example 1: Filtering Data - Select individuals with high capital-gain (above 5000)
high_capital_gain = data[data["capital-gain"] > 5000]

# Example 2: Filtering Data - Select individuals with a Bachelor's degree and salary >50K
bachelors_high_income = data[(data["education"] == "Bachelors") & (data["salary"] == " >50K")]

# Example 3: Merging Data - Assume we have another dataset (dummy example)
# Creating a sample DataFrame to merge with the main data (Example: demographic regions)
region_data = pd.DataFrame({
    "native-country": ["United-States", "Mexico", "India"],
    "region": ["North America", "North America", "Asia"]
})

# Merging the datasets on 'native-country' column
merged_data = data.merge(region_data, on="native-country", how="left")

# %%
merged_data
# Out:
#        age         workclass   education  education-num      marital-status  \
# 0       39         State-gov   Bachelors             13       Never-married
# 1       50  Self-emp-not-inc   Bachelors             13  Married-civ-spouse
# 2       38           Private     HS-grad              9            Divorced
# 3       53           Private        11th              7  Married-civ-spouse
# 4       28           Private   Bachelors             13  Married-civ-spouse
# ...    ...               ...         ...            ...                 ...
# 32556   27           Private  Assoc-acdm             12  Married-civ-spouse
# 32557   40           Private     HS-grad              9  Married-civ-spouse
# 32558   58           Private     HS-grad              9             Widowed
# 32559   22           Private     HS-grad              9       Never-married
# 32560   52      Self-emp-inc     HS-grad              9  Married-civ-spouse
#
# ...

# %%
# Group by race and find the maximum age for each race
max_age_by_race = data.groupby("race")["age"].max().reset_index()
max_age_by_race.columns = ["Race", "Max Age"]


# Plot the maximum age across races
plt.figure(figsize=(8, 5))
sns.barplot(x=max_age_by_race["Race"], y=max_age_by_race["Max Age"], palette="viridis")
plt.xticks(rotation=45)
plt.title("Maximum Age Across Races")
plt.xlabel("Race")
plt.ylabel("Max Age")
plt.show()

# %%
# Find the oldest individual for each race
oldest_individuals_by_race = data.loc[data.groupby("race")["age"].idxmax()]

oldest_individuals_by_race
# Out:
#        age workclass     education  education-num      marital-status  \
# 12492   82         ?  Some-college             10             Widowed
# 2303    90   Private  Some-college             10       Never-married
# 222     90   Private       HS-grad              9       Never-married
# 12670   77   Private       7th-8th              4  Married-civ-spouse
# 1040    90   Private       HS-grad              9       Never-married
#
#               occupation   relationship                race     sex  \
# 12492                  ?  Not-in-family  Amer-Indian-Eskimo    Male
# 2303       Other-service  Not-in-family  Asian-Pac-Islander    Male
# 222        Other-service  Not-in-family               Black    Male
# 12670  Machine-op-inspct        Husband               Other    Male
# 1040       Other-service  Not-in-family               White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# ...

# %%
# Create a boxplot to visualize the relationship between education and capital-gain
plt.figure(figsize=(12, 6))
sns.boxplot(x=data["education"], y=data["capital-gain"], palette="viridis")
plt.xticks(rotation=90)
plt.title("Capital-Gain Distribution Across Education Levels")
plt.xlabel("Education Level")
plt.ylabel("Capital-Gain")
plt.show()

# Compute the average capital-gain per education level
capital_gain_by_education = data.groupby("education")["capital-gain"].mean().reset_index()
capital_gain_by_education.columns = ["Education", "Avg Capital-Gain"]


# Create a bar plot for average capital-gain per education level
plt.figure(figsize=(12, 6))
sns.barplot(x=capital_gain_by_education["Education"], y=capital_gain_by_education["Avg Capital-Gain"], palette="magma")
plt.xticks(rotation=90)
plt.title("Average Capital-Gain by Education Level")
plt.xlabel("Education Level")
plt.ylabel("Average Capital-Gain")
plt.show()

# %%
# Create a histogram for capital-gain distribution
plt.figure(figsize=(8, 5))
sns.histplot(data["capital-gain"], bins=30, kde=True, color="blue", alpha=0.6)
plt.title("Histogram of Capital-Gain Distribution")
plt.xlabel("Capital-Gain")
plt.ylabel("Frequency")
plt.show()

# Create a boxplot for capital-gain distribution
plt.figure(figsize=(6, 4))
sns.boxplot(y=data["capital-gain"], color="purple")
plt.title("Boxplot of Capital-Gain Distribution")
plt.ylabel("Capital-Gain")
plt.show()

# %%
# Separate the dataset into male and female records
male_records = data[data["sex"] == "Male"]
female_records = data[data["sex"] == "Female"]

# %%
male_records 
female_records
# Out:
#        age     workclass     education  education-num         marital-status  \
# 4       28       Private     Bachelors             13     Married-civ-spouse
# 5       37       Private       Masters             14     Married-civ-spouse
# 6       49       Private           9th              5  Married-spouse-absent
# 8       31       Private       Masters             14          Never-married
# 12      23       Private     Bachelors             13          Never-married
# ...    ...           ...           ...            ...                    ...
# 32546   37       Private    Assoc-acdm             12               Divorced
# 32549   43     State-gov  Some-college             10               Divorced
# 32556   27       Private    Assoc-acdm             12     Married-civ-spouse
# 32558   58       Private       HS-grad              9                Widowed
# 32560   52  Self-emp-inc       HS-grad              9     Married-civ-spouse
#
# ...

# %%
# Create a boxplot to compare age distributions across education levels
plt.figure(figsize=(12, 6))
sns.boxplot(x=data["education"], y=data["age"], palette="viridis")

plt.xticks(rotation=90)
plt.title("Boxplot of Age by Education Level")
plt.xlabel("Education Level")
plt.ylabel("Age")
plt.show()

# %%
# Count missing values for each column
missing_values = data.isnull().sum().reset_index()
missing_values.columns = ["Column", "Missing Values"]

missing_values
# Out:
#             Column  Missing Values
# 0              age               0
# 1        workclass               0
# 2        education               0
# 3    education-num               0
# 4   marital-status               0
# 5       occupation               0
# 6     relationship               0
# 7             race               0
# 8              sex               0
# 9     capital-gain               0
# 10    capital-loss               0
# 11  hours-per-week               0
# 12  native-country               0
# 13          salary               0

# %%
from sklearn.preprocessing import LabelEncoder

# Identify categorical columns
categorical_columns = data.select_dtypes(include=["object"]).columns

# Apply Label Encoding to each categorical column
label_encoders = {}
for col in categorical_columns:
    label_encoders[col] = LabelEncoder()
    data[col] = label_encoders[col].fit_transform(data[col])

# %%
categorical_columns
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country', 'salary'],
#       dtype='object')

# %%
# Count non-US migrants (individuals whose native-country is not 'United-States')
non_us_migrants = data[data["native-country"] != label_encoders["native-country"].transform(["United-States"])[0]]

# Count occurrences of each non-US country
migration_counts = non_us_migrants["native-country"].value_counts().reset_index()
migration_counts.columns = ["Country", "Count"]


# Plot the migration patterns in a bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x=migration_counts["Country"], y=migration_counts["Count"], palette="magma")
plt.xticks(rotation=90)
plt.title("Non-US Migrants by Country")
plt.xlabel("Country")
plt.ylabel("Count")
plt.show()

# %%
data.describe().T
# Out:
#                   count         mean          std   min   25%   50%   75%  \
# age             32561.0    38.581647    13.640433  17.0  28.0  37.0  48.0
# workclass       32561.0     3.868892     1.455960   0.0   4.0   4.0   4.0
# education       32561.0    10.298210     3.870264   0.0   9.0  11.0  12.0
# education-num   32561.0    10.080679     2.572720   1.0   9.0  10.0  12.0
# marital-status  32561.0     2.611836     1.506222   0.0   2.0   2.0   4.0
# occupation      32561.0     6.572740     4.228857   0.0   3.0   7.0  10.0
# relationship    32561.0     1.446362     1.606771   0.0   0.0   1.0   3.0
# race            32561.0     3.665858     0.848806   0.0   4.0   4.0   4.0
# sex             32561.0     0.669205     0.470506   0.0   0.0   1.0   1.0
# capital-gain    32561.0  1077.648844  7385.292085   0.0   0.0   0.0   0.0
# capital-loss    32561.0    87.303830   402.960219   0.0   0.0   0.0   0.0
# hours-per-week  32561.0    40.437456    12.347429   1.0  40.0  40.0  45.0
# ...

# %%
data.iloc[14]
# Out:
# age               40
# workclass          4
# education          8
# education-num     11
# marital-status     2
# occupation         3
# relationship       0
# race               1
# sex                1
# capital-gain       0
# capital-loss       0
# hours-per-week    40
# native-country     0
# salary             1
# Name: 14, dtype: int64

# %%
data["education"].unique
# Out:
# <bound method Series.unique of 0         9
# 1         9
# 2        11
# 3         1
# 4         9
#          ..
# 32556     7
# 32557    11
# 32558    11
# 32559    11
# 32560    11
# Name: education, Length: 32561, dtype: int32>

# %%
data["education"].value_counts()
# Out:
# 11    10501
# 15     7291
# 9      5355
# 12     1723
# 8      1382
# 1      1175
# 7      1067
# 0       933
# 5       646
# 14      576
# 6       514
# 2       433
# 10      413
# 4       333
# 3       168
# 13       51
# Name: education, dtype: int64

# %%
salary_counts = data["salary"].value_counts()
print("\nsalary Distribution:")
print(salary_counts)
# Out:
# salary Distribution:
# 0    24720
# 1     7841
# Name: salary, dtype: int64

# %%
gender_salary = data.groupby(["sex", "salary"]).size()
print("\nsalary by Gender:")
print(gender_salary)
# Out:
# salary by Gender:
# sex  salary
# 0    0          9592
#      1          1179
# 1    0         15128
#      1          6662
# dtype: int64

# %%
education_salary = data.groupby(["education", "salary"]).size().unstack()

# %%
print("\n **Education vs. salary:**")
print(education_salary)
# Out:
#  **Education vs. salary:**
# salary          0       1
# education
# 0           871.0    62.0
# 1          1115.0    60.0
# 2           400.0    33.0
# 3           162.0     6.0
# 4           317.0    16.0
# 5           606.0    40.0
# 6           487.0    27.0
# 7           802.0   265.0
# 8          1021.0   361.0
# 9          3134.0  2221.0
# 10          107.0   306.0
# 11         8826.0  1675.0
# 12          764.0   959.0
# 13           51.0     NaN
# 14          153.0   423.0
# 15         5904.0  1387.0

# %%
education_salary.plot(kind="bar", stacked=True)
# Out:
# <AxesSubplot:xlabel='education'>

# %%
gender_income = data.groupby(["sex", "salary"]).size()
print("\n**salarye by Gender:**")
print(gender_salary)
# Out:
# **salarye by Gender:**
# sex  salary
# 0    0          9592
#      1          1179
# 1    0         15128
#      1          6662
# dtype: int64

# %%
gender_salary = data.groupby(["sex", "salary"]).size().unstack()
print("\n**Salary by Gender:**")
print(gender_salary)
# Out:
# **Salary by Gender:**
# salary      0     1
# sex
# 0        9592  1179
# 1       15128  6662

# %%
education_salary = data.groupby(["education", "salary"]).size().unstack()
print("\n**Education vs. salary:**")
print(education_salary)
# Out:
# **Education vs. salary:**
# salary          0       1
# education
# 0           871.0    62.0
# 1          1115.0    60.0
# 2           400.0    33.0
# 3           162.0     6.0
# 4           317.0    16.0
# 5           606.0    40.0
# 6           487.0    27.0
# 7           802.0   265.0
# 8          1021.0   361.0
# 9          3134.0  2221.0
# 10          107.0   306.0
# 11         8826.0  1675.0
# 12          764.0   959.0
# 13           51.0     NaN
# 14          153.0   423.0
# 15         5904.0  1387.0

# %%
education_salary.plot(kind="bar", stacked=True)
plt.xlabel("Education Level")
plt.ylabel("Count")
plt.title("Education Level vs. Salary")
plt.legend(title="Salary")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(data["age"], bins=30, kde=True, color="blue")
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(y=data["workclass"], order=data["workclass"].value_counts().index, color="blue")
plt.title("Workclass Distribution")
plt.xlabel("Count")
plt.ylabel("Workclass")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
sns.countplot(y=data["workclass"], hue=data["salary"], 
              order=data["workclass"].value_counts().index, 
              palette="magma")  # Removed `legend=False`

plt.title("Workclass Distribution")
plt.xlabel("Count")
plt.ylabel("Workclass")
plt.legend(title="Salary")  # If needed, customize the legend here
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="salary", hue="sex", data=data, palette="coolwarm")
plt.title("salary Distribution by Gender")
plt.xlabel("salary")
plt.ylabel("Count")
plt.show()

# %%
# Hours per week vs Salary
plt.figure(figsize=(10, 5))
sns.boxplot(x="salary", y="hours-per-week", hue="salary", data=data, palette="Set1", dodge=False)  # Changed "income" to "salary"
plt.title("Hours Worked Per Week by Salary Class")  # Updated title
plt.xlabel("Salary")  # Changed label from "Income" to "Salary"
plt.ylabel("Hours per Week")
plt.show()

# Convert categorical columns into numerical representations
categorical_cols = data.select_dtypes(include=["object"]).columns  # Identifies categorical columns
df_encoded = pd.get_dummies(data, columns=categorical_cols, drop_first=True)  # Converts categorical variables into numeric form using one

df_encoded
# Out:
#        age  workclass  education  education-num  marital-status  occupation  \
# 0       39          7          9             13               4           1
# 1       50          6          9             13               2           4
# 2       38          4         11              9               0           6
# 3       53          4          1              7               2           6
# 4       28          4          9             13               2          10
# ...    ...        ...        ...            ...             ...         ...
# 32556   27          4          7             12               2          13
# 32557   40          4         11              9               2           7
# 32558   58          4         11              9               6           1
# 32559   22          4         11              9               4           1
# 32560   52          5         11              9               2           4
#
# ...

# %%
print(data.columns)  # Verify if "hours_per_week" exists
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'salary'],
#       dtype='object')

# %%
# Convert categorical columns into numerical representations
categorical_cols = data.select_dtypes(include=["object"]).columns  # Identifies categorical columns
df_encoded = pd.get_dummies(data, columns=categorical_cols, drop_first=True)  # Converts categorical variables into numeric form using one-hot encoding

# Display the shape of the encoded dataset
print(df_encoded.shape)

# Correlation matrix visualization
plt.figure(figsize=(10, 6))
sns.heatmap(df_encoded.corr(), cmap="coolwarm", annot=False)  # Ensure function call is complete
plt.title("Correlation Matrix")
plt.show()

# Encoding salary using LabelEncoder
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
data["salary"] = encoder.fit_transform(data["salary"])  # Changed "income" to "salary"

# Salary distribution by gender visualization (Vertical Bar Chart)
plt.figure(figsize=(6, 4))
sns.countplot(x="salary", hue="sex", data=data, palette="coolwarm")  # Changed "income" to "salary"
plt.title("Salary Distribution by Gender")  # Ensure title is fully written
plt.xlabel("Salary")  # Changed label from "Income" to "Salary"
plt.ylabel("Count")
plt.show()
# Out:
# (32561, 14)

# %%
# Convert categorical columns into numerical representations
categorical_cols = data.select_dtypes(include=["object"]).columns  # Identifies categorical columns
df_encoded = pd.get_dummies(data, columns=categorical_cols, drop_first=True)  # Converts categorical variables into numeric form using one-hot encoding

# Display the shape of the encoded dataset
print(df_encoded.shape)

# Correlation matrix visualization
plt.figure(figsize=(10, 6))
sns.heatmap(df_encoded.corr(), cmap="coolwarm", annot=False)  # Ensure function call is complete
plt.title("Correlation Matrix")
plt.show()

# Encoding salary using LabelEncoder
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
data["salary"] = encoder.fit_transform(data["salary"])  # Changed "income" to "salary"

# Salary distribution by gender visualization (Vertical Bar Chart)
plt.figure(figsize=(6, 4))
sns.countplot(x="salary", hue="sex", data=data, palette="coolwarm")  # Changed "income" to "salary"
plt.title("Salary Distribution by Gender")  # Ensure title is fully written
plt.xlabel("Salary")  # Changed label from "Income" to "Salary"
plt.ylabel("Count")
plt.show()

# %%
# Convert categorical columns into numerical representations
categorical_cols = data.select_dtypes(include=["object"]).columns  # Identifies categorical columns
df_encoded = pd.get_dummies(data, columns=categorical_cols, drop_first=True)  # Converts categorical variables into numeric form using one-hot encoding

# Display the shape of the encoded dataset
print(df_encoded.shape)

# Correlation matrix visualization
plt.figure(figsize=(10, 6))
sns.heatmap(df_encoded.corr(), cmap="coolwarm", annot=False)  # Ensure function call is complete
plt.title("Correlation Matrix")
plt.show()

# Encoding salary using LabelEncoder
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
data["salary"] = encoder.fit_transform(data["salary"])  # Changed "income" to "salary"

# Salary distribution by gender visualization (Vertical Bar Chart)
plt.figure(figsize=(6, 4))
sns.countplot(x="salary", hue="sex", data=data, palette="coolwarm")  # Changed "income" to "salary"
plt.title("Salary Distribution by Gender")  # Ensure title is fully written
plt.xlabel("Salary")  # Changed label from "Income" to "Salary"
plt.ylabel("Count")
plt.show()
# Out:
# (32561, 14)
