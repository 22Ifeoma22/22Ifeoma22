# %% [markdown]
# <a href="https://colab.research.google.com/github/22Ifeoma22/22Ifeoma22/blob/main/ExploringAutomobileMpgDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %%
automobile_df = pd.read_csv("/content/sample_data/mpg_raw.csv")

# %%
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 183  25.0          4         116.0        81.0    2220          16.9
# 196  24.5          4          98.0        60.0    2164          22.1
# 168  23.0          4         140.0        83.0    2639          17.0
# 386  25.0          6         181.0       110.0    2945          16.4
# 285  17.0          8         305.0       130.0    3840          15.4
#
#      model_year  origin                       name
# 183          76  europe                  opel 1900
# 196          76     usa            chevrolet woody
# 168          75     usa                 ford pinto
# 386          82     usa      buick century limited
# 285          79     usa  chevrolet caprice classic

# %%
automobile_df.shape
# Out:
# (398, 9)

# %%
automobile_df = automobile_df.dropna()

# %%
automobile_df.shape
# Out:
# (392, 9)

# %%
automobile_df.drop(['origin', 'name'], axis=1, inplace=True)

# %%
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 239  30.0          4          97.0        67.0    1985          16.4
# 295  35.7          4          98.0        80.0    1915          14.4
# 117  29.0          4          68.0        49.0    1867          19.5
# 358  31.6          4         120.0        74.0    2635          18.3
# 170  23.0          4         140.0        78.0    2592          18.5
#
#      model_year
# 239          77
# 295          79
# 117          73
# 358          81
# 170          75

# %%
automobile_df['model_year'] = '19' + automobile_df['model_year'].astype(str)

# %%
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 48   18.0          6         250.0        88.0    3139          14.5
# 81   28.0          4          97.0        92.0    2288          17.0
# 12   15.0          8         400.0       150.0    3761           9.5
# 155  15.0          6         250.0        72.0    3158          19.5
# 272  23.8          4         151.0        85.0    2855          17.6
#
#     model_year
# 48        1971
# 81        1972
# 12        1970
# 155       1975
# 272       1978

# %%
automobile_df['age'] = datetime.datetime.now().year - pd.to_numeric(automobile_df['model_year'])

# %%
automobile_df.drop(['model_year'], axis=1, inplace=True)

# %%
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  age
# 249  19.9          8         260.0       110.0    3365          15.5   46
# 173  24.0          4         119.0        97.0    2545          17.0   49
# 108  20.0          4          97.0        88.0    2279          19.0   51
# 262  19.2          8         305.0       145.0    3425          13.2   46
# 347  37.0          4          85.0        65.0    1975          19.4   43

# %%
automobile_df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# age               int64
# dtype: object

# %%
automobile_df['horsepower'] = pd.to_numeric(automobile_df['horsepower'], errors='coerce')

# %%
automobile_df.describe()# quick feel of numeric data
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration         age
# count    392.000000  392.000000
# mean      15.541327   48.020408
# std        2.758864    3.683737
# min        8.000000   42.000000
# 25%       13.775000   45.000000
# 50%       15.500000   48.000000
# 75%       17.025000   51.000000
# max       24.800000   54.000000

# %% [markdown]
# #  Exploring and visualizing relationships in data

# %%
fig, ax = plt.subplots(figsize=(12, 8))
plt.scatter(automobile_df['age'], automobile_df['mpg'])
plt.xlabel('Age')
plt.ylabel('Miles per gallon')
# Out:
# Text(0, 0.5, 'Miles per gallon')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
plt.scatter(automobile_df['acceleration'], automobile_df['mpg'])
plt.xlabel('Acceleration')
plt.ylabel('Miles per gallon')
# Out:
# Text(0, 0.5, 'Miles per gallon')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
plt.scatter(automobile_df['weight'], automobile_df['mpg'])
plt.xlabel('Weight')
plt.ylabel('Miles per gallon')
# Out:
# Text(0, 0.5, 'Miles per gallon')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
plt.scatter(automobile_df['displacement'], automobile_df['mpg'])
plt.xlabel('Displacement')
plt.ylabel('Miles per gallon')
# Out:
# Text(0, 0.5, 'Miles per gallon')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
plt.scatter(automobile_df['horsepower'], automobile_df['mpg'])
plt.xlabel('Horsepower')
plt.ylabel('Miles per gallon')
# Out:
# Text(0, 0.5, 'Miles per gallon')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
plt.scatter(automobile_df['cylinders'], automobile_df['mpg'])
plt.xlabel('Cylinders')
plt.ylabel('Miles per gallon')
# Out:
# Text(0, 0.5, 'Miles per gallon')

# %%
automobile_corr = automobile_df.corr()
automobile_corr
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# age          -0.580541   0.345647      0.369855    0.416361  0.309120
#
#               acceleration       age
# mpg               0.423329 -0.580541
# cylinders        -0.504683  0.345647
# displacement     -0.543800  0.369855
# horsepower       -0.689196  0.416361
# weight           -0.416839  0.309120
# acceleration      1.000000 -0.290316
# age              -0.290316  1.000000

# %%
fig, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(automobile_corr, annot=True)
# Out:
# <Axes: >

# %%
automobile_df = automobile_df.sample(frac=1).reset_index(drop=True)
automobile_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  age
# 0  20.0          8         262.0       110.0    3221          13.5   49
# 1  18.0          6         199.0        97.0    2774          15.5   54
# 2  23.7          3          70.0       100.0    2420          12.5   44
# 3  20.5          6         200.0        95.0    3155          18.2   46
# 4  13.0          8         318.0       150.0    3755          14.0   48

# %% [markdown]
# #Shuffle data is important so that our data does not pick up patterns that do not exist

# %%
automobile_df.to_csv("/content/sample_data/auto-mpg-processed.csv")

# %%
# !ls sample_data/
# Out:
# anscombe.json		california_housing_test.csv   mnist_train_small.csv
# Automobile_data.csv	california_housing_train.csv  mpg_raw.csv
# auto-mpg-processed.csv	mnist_test.csv		      README.md
